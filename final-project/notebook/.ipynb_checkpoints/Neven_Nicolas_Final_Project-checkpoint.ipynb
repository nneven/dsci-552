# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

tf.get_logger().setLevel('ERROR')

# %% [markdown]
# # Question (1) (a) (b)

# %%
full_dataset = tf.keras.preprocessing.image_dataset_from_directory('../data/images',
                                                                   label_mode='categorical',
                                                                   batch_size=5)
# Out:
# Found 1236 files belonging to 21 classes.

# %%
full_dataset_size = len(list(full_dataset))
train_dataset_size = int(0.7 * full_dataset_size)
validate_dataset_size = int(0.15 * full_dataset_size)

train_dataset = full_dataset.take(train_dataset_size)
remaining = full_dataset.skip(train_dataset_size)  
validate_dataset = remaining.take(validate_dataset_size)
test_dataset = remaining.skip(validate_dataset_size)
# Out:
# 2022-12-04 20:52:21.819681: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz

# %%
print('Number of training batches: %d' % tf.data.experimental.cardinality(train_dataset))
print('Number of validation batches: %d' % tf.data.experimental.cardinality(validate_dataset))
print('Number of test batches: %d' % tf.data.experimental.cardinality(test_dataset))
# Out:
# Number of training batches: 173
# Number of validation batches: 37
# Number of test batches: 38

# %%
# class_names = train_dataset.class_names

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
    for i in range(3):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        # plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)
validation_dataset = validate_dataset.prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # Question (1) (c)

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomCrop(height=256, width=256),
    tf.keras.layers.RandomZoom(height_factor=(-0.2, 0.2)),
    tf.keras.layers.RandomRotation(factor=(-0.2, 0.2)),
    tf.keras.layers.RandomFlip(),
    tf.keras.layers.RandomContrast(factor=0.2),
    tf.keras.layers.RandomTranslation(height_factor=(-0.2, 0.2), width_factor=(-0.2, 0.2))
])

# %%
for image, _ in train_dataset.take(1):
    plt.figure(figsize=(10, 10))
    first_image = image[0]
    for i in range(3):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image = data_augmentation(tf.expand_dims(first_image, 0))
        plt.imshow(augmented_image[0] / 255)
        plt.axis('off')
# Out:
# 2022-12-04 20:52:24.026537: W tensorflow/core/grappler/optimizers/loop_optimizer.cc:907] Skipping loop optimization for Merge node with control input: loop_body/cond/branch_executed/_9
# 2022-12-04 20:52:25.680532: W tensorflow/core/grappler/optimizers/loop_optimizer.cc:907] Skipping loop optimization for Merge node with control input: loop_body/cond/branch_executed/_9
# 2022-12-04 20:52:27.236503: W tensorflow/core/grappler/optimizers/loop_optimizer.cc:907] Skipping loop optimization for Merge node with control input: loop_body/cond/pfor/cond/branch_executed/_191

# %%
base_model = tf.keras.applications.EfficientNetB0(include_top=False)

# %%
image_batch, label_batch = next(iter(train_dataset))
feature_batch = base_model(image_batch)
print(feature_batch.shape)
# Out:
# (5, 8, 8, 1280)

# %%
base_model.trainable = False

# %%
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()
feature_batch_average = global_average_layer(feature_batch)
print(feature_batch_average.shape)
# Out:
# (5, 1280)

# %%
prediction_layer = tf.keras.layers.Dense(21, activation='softmax')
prediction_batch = prediction_layer(feature_batch_average)
print(prediction_batch.shape)
# Out:
# (5, 21)

# %%
inputs = tf.keras.Input(shape=(256, 256, 3))
x = data_augmentation(inputs)
x = base_model(x, training=False)
x = global_average_layer(x)
x = tf.keras.layers.Dense(1280, activation='relu')(x)
x = tf.keras.layers.Dropout(0.2)(x)
outputs = prediction_layer(x)
model = tf.keras.Model(name='EfficientNetB0', inputs=inputs, outputs=outputs)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "EfficientNetB0"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  sequential (Sequential)     (None, 256, 256, 3)       0
#
#  efficientnetb0 (Functional)  (None, None, None, 1280)  4049571
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 1280)              1639680
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 21)                26901
#
# =================================================================
# Total params: 5,716,152
# Trainable params: 1,666,581
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %%
len(model.trainable_variables)
# Out:
# 4

# %%
loss0, accuracy0 = model.evaluate(validate_dataset)
# Out:
# 37/37 [==============================] - 5s 105ms/step - loss: 3.0505 - accuracy: 0.0216

# %%
print("Initial Loss: {:.2f}".format(loss0))
print("Initial Accuracy: {:.2f}".format(accuracy0))
# Out:
# Initial Loss: 3.05
# Initial Accuracy: 0.02

# %%
history = model.fit(train_dataset,
                    epochs=100,
                    validation_data=validate_dataset)
# Out:
# Epoch 1/100
# 2022-12-04 20:52:40.743161: W tensorflow/core/grappler/optimizers/loop_optimizer.cc:907] Skipping loop optimization for Merge node with control input: EfficientNetB0/sequential/random_crop/loop_body/cond/branch_executed/_9
# 173/173 [==============================] - 29s 134ms/step - loss: 1.2228 - accuracy: 0.6312 - val_loss: 0.4159 - val_accuracy: 0.8703
# Epoch 2/100
# 173/173 [==============================] - 18s 106ms/step - loss: 0.5265 - accuracy: 0.8335 - val_loss: 0.3419 - val_accuracy: 0.8919
# Epoch 3/100
# 173/173 [==============================] - 20s 115ms/step - loss: 0.3527 - accuracy: 0.8867 - val_loss: 0.3709 - val_accuracy: 0.9081
# Epoch 4/100
# 173/173 [==============================] - 19s 113ms/step - loss: 0.2710 - accuracy: 0.9133 - val_loss: 0.3186 - val_accuracy: 0.9135
# Epoch 5/100
# 173/173 [==============================] - 18s 102ms/step - loss: 0.2426 - accuracy: 0.9214 - val_loss: 0.2380 - val_accuracy: 0.9297
# Epoch 6/100
# 173/173 [==============================] - 18s 104ms/step - loss: 0